# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\nadys\Desktop\Projects\data\StudentsPerformance.csv')

data.head(3)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %%
data['math score'].hist()
# Out:
# <Axes: >

# %%
data.plot.scatter(x='math score', y='reading score')
# Out:
# <Axes: xlabel='math score', ylabel='reading score'>

# %%
sns.lmplot(data=data, x='math score', y='reading score', hue='gender')

# %%
data = pd.read_csv(r'C:\Users\nadys\Desktop\Projects\data\dota_hero_stats.csv')

roles_sum = []
for i in data['roles']:
    roles_sum.append(len(i.split()))

data['roles_sum'] = roles_sum
data[['localized_name','roles_sum']].groupby('roles_sum').aggregate({'localized_name': ['count']})
# Out:
#           localized_name
#                    count
# roles_sum
# 1                      1
# 2                      9
# 3                     28
# 4                     38
# 5                     33
# 6                      8

# %%
data = pd.read_csv(r'C:\Users\nadys\Desktop\Projects\data\iris.csv').drop('Unnamed: 0', axis=1)

data.head()

sns.kdeplot(data.iloc[:, :])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.pairplot(data)

# %%
data.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0
