# %%
import pandas as pd
import seaborn as sns

data = pd.read_excel(r'C:\Users\nadys\Desktop\DE.xlsx')

data = pd.merge(data['Отношение диаметра к объему раствора'], data['Абсолютное снижение СЭ, %'], right_index=True, left_index=True)
data = data.dropna()
data

sns.scatterplot(x=data['Отношение диаметра к объему раствора'], y=data['Абсолютное снижение СЭ, %'])
# Out:
# <Axes: xlabel='Отношение диаметра к объему раствора', ylabel='Абсолютное снижение СЭ, %'>
