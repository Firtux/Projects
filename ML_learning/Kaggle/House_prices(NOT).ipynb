# %% [markdown]
# **Kaggle**
#
# House Prices - Advanced Regression Techniques
#
# https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data

# %%
import pandas as pd
import seaborn as sns

# %%
house_prices_train = pd.read_csv(r'https://drive.google.com/uc?export=download&id=1JXzryWB1VstGi5J8OSyvRidYY0S9PR4s')

# %%
house_prices_train.head().T
# Out:
#                     0       1       2        3       4
# Id                  1       2       3        4       5
# MSSubClass         60      20      60       70      60
# MSZoning           RL      RL      RL       RL      RL
# LotFrontage      65.0    80.0    68.0     60.0    84.0
# LotArea          8450    9600   11250     9550   14260
# ...               ...     ...     ...      ...     ...
# MoSold              2       5       9        2      12
# YrSold           2008    2007    2008     2006    2008
# SaleType           WD      WD      WD       WD      WD
# SaleCondition  Normal  Normal  Normal  Abnorml  Normal
# SalePrice      208500  181500  223500   140000  250000
#
# [81 rows x 5 columns]

# %%
data = house_prices_train[['LotFrontage', 'LotArea', 'SalePrice']]

sns.pairplot(data)

# %%
data.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_0e573_row0_col0, #T_0e573_row1_col1, #T_0e573_row2_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_0e573_row0_col1 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_0e573_row0_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_0e573_row1_col0 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_0e573_row1_col2, #T_0e573_row2_col0, #T_0e573_row2_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_0e573">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e573_level0_col0" class="col_heading level0 col0" >LotFrontage</th>
#       <th id="T_0e573_level0_col1" class="col_heading level0 col1" >LotArea</th>
#       <th id="T_0e573_level0_col2" class="col_heading level0 col2" >SalePrice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e573_level0_row0" class="row_heading level0 row0" >LotFrontage</th>
# ...
