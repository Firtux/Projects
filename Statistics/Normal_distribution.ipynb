# %%
import scipy.stats as sps
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
sample = sps.norm(77.8, 0.5).rvs(5)
aver = sum(sample)/len(sample)

# %%
plt.figure(figsize=(4, 3))
sns.kdeplot(sample)
# sns.histplot(sample)
plt.show()

# %%
# QQ plot with statsmodels and matplotlib

sm.qqplot(sample, line='s')
plt.show()

# %%
# QQ plot with seaborn and matplotlib

sps.probplot(sample, dist="norm", plot=pylab)
plt.show()
