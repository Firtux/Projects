# %%
from sklearn import datasets
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

X, y = datasets.load_diabetes(as_frame=True, return_X_y=True)

# data = y['age'] = X.age

# data = pd.concat([y, X.age])

# display(X)
# display(y)

age = X[['age']]

data = pd.concat([y, age], axis=1)

lr = LinearRegression().fit(age, y)

predicted = lr.predict(age)

print(lr.coef_)
X.corr().style.background_gradient(cmap = 'coolwarm')
# Out:
# [304.18307453]
# <style type="text/css">
# #T_ef2be_row0_col0, #T_ef2be_row1_col1, #T_ef2be_row2_col2, #T_ef2be_row3_col3, #T_ef2be_row4_col4, #T_ef2be_row5_col5, #T_ef2be_row6_col6, #T_ef2be_row7_col7, #T_ef2be_row8_col8, #T_ef2be_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ef2be_row0_col1 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_ef2be_row0_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_ef2be_row0_col3 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_ef2be_row0_col4, #T_ef2be_row1_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_ef2be_row0_col5 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_ef2be_row0_col6, #T_ef2be_row2_col5, #T_ef2be_row3_col0 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_ef2be_row0_col7, #T_ef2be_row7_col9 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_ef2be_row0_col8 {
#   background-color: #d7dce3;
# ...

# %%
plt.scatter(age, y)
plt.plot(age, predicted, c='r')
plt.show()

# %%
print(diab.feature_names)
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
y
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: target, Length: 442, dtype: float64
