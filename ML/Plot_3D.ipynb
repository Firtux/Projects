# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

data = pd.read_csv(r'C:\Users\nadys\Desktop\Projects\data\states.csv')

x = data[['white', 'hs_grad']]
z = data['poverty']

model = LinearRegression()
z = model.fit(x, z).predict(x)
z = pd.DataFrame(z, columns=['povetry'])
LR_frame = pd.merge(x, z, left_index=True, right_index=True)
LR_frame.head()

# labels = ['hs_grad', 'white', 'povetry']
# surface_plot_3D(data['hs_grad'], data['white'], z, labels)
# Out:
#    white  hs_grad    povetry
# 0   71.3     79.9  15.299903
# 1   70.8     90.6   8.961905
# 2   87.7     83.8  12.477597
# 3   81.0     80.9  14.406508
# 4   77.5     81.1  14.395861

# %%
data = pd.read_csv(r'C:\Users\nadys\Desktop\Projects\data\states.csv')

x = data['white']
y = data['hs_grad']
z = data['poverty']

import plotly.graph_objects as go

def scatter_plot_3D(x, y, z):
    fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z,
                    mode='markers',
                    marker=dict(
                        size=5,
                        color='blue',                # set color to an array/list of desired values
                        colorscale='Viridis',   # choose a colorscale
                        opacity=1))])
    fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
    fig.show()

scatter_plot_3D(x, y, z)

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

data = pd.read_csv('http://d396qusza40orc.cloudfront.net/statistics/lec_resources/states.csv')

X = data[['white', 'hs_grad']]
y = data['poverty']

reg = LinearRegression().fit(X, y)

d1, d2 = list(), list()
for x in np.linspace(min(data['white']), max(data['white']), 100):
    for y in np.linspace(min(data['hs_grad']), max(data['hs_grad']), 100):
        d1.append(x)
        d2.append(y)
d1 = np.array(d1).reshape(-1, 1)
d2 = np.array(d2).reshape(-1, 1)
p = reg.predict(np.concatenate([d1, d2], axis=1))
print(d1)

# fig = plt.figure(figsize=(8, 8))
# ax = plt.axes(projection='3d')

# ax.scatter(data['hs_grad'], data['white'], data['poverty'], s=50)

# ax.plot_trisurf(d2.ravel(), d1.ravel(), p.ravel(), alpha=0.2)

# ax.set_xlabel('Higher education(%)')
# ax.set_ylabel('White(%)')
# ax.set_zlabel('Poverty(%)')

# ax.elev = 10
# ax.azim = -60

# plt.show()
# Out:
# [[25.9]
#  [25.9]
#  [25.9]
#  ...
#  [97.1]
#  [97.1]
#  [97.1]]
# c:\Users\nadys\Desktop\Projects\myenv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names

# %%
import plotly.graph_objects as go
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np

data = pd.read_csv(r'C:\Users\nadys\Desktop\Projects\data\states.csv')

x = data[['white', 'hs_grad']]
z = data['poverty']

model = LinearRegression()
z = model.fit(x, z)
# z = model.intercept_+model.coef_[0]*x+model.coef_[1]*y
# x, y = np.linspace(0, 1, 51), np.linspace(0, 1, 51)

d1, d2 = list(), list()
for x in np.linspace(min(data['white']), max(data['white']), 100):
    for y in np.linspace(min(data['hs_grad']), max(data['hs_grad']), 100):
        d1.append(x)
        d2.append(y)
d1 = np.array(d1).reshape(-1, 1)
d2 = np.array(d2).reshape(-1, 1)
p = z.predict(np.concatenate([d1, d2], axis=1))
print(np.concatenate([d1, d2], axis=1))
fig = go.Figure(data=[go.Surface(z=p, x=d1, y=d2)])

fig.show()
# Out:
# [[25.9        77.2       ]
#  [25.9        77.35050505]
#  [25.9        77.5010101 ]
#  ...
#  [97.1        91.7989899 ]
#  [97.1        91.94949495]
#  [97.1        92.1       ]]
# c:\Users\nadys\Desktop\Projects\myenv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np
# Read data from a csv
z = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')
print(z_data.values)
# sh_0, sh_1 = z.shape
# x, y = np.linspace(0, 1, sh_0), np.linspace(0, 1, sh_1)

fig = go.Figure(data=[go.Surface(z=z)])
fig.update_layout(title=dict(text='Mt Bruno Elevation'), autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))
fig.show()
# Out:
# [[ 0.000000e+00  2.780985e+01  4.961936e+01  8.308067e+01  1.166632e+02
#    1.304140e+02  1.507206e+02  2.201871e+02  1.561536e+02  1.486416e+02
#    2.037845e+02  2.060386e+02  1.071618e+02  6.836975e+01  4.533590e+01
#    4.996142e+01  2.189279e+01  1.702552e+01  1.174317e+01  1.475226e+01
#    1.366710e+01  5.677561e+00  3.312340e+00  1.156517e+00 -1.476620e-01]
#  [ 1.000000e+00  2.771966e+01  4.855022e+01  6.521374e+01  9.527666e+01
#    1.169964e+02  1.339056e+02  1.523412e+02  1.519340e+02  1.601139e+02
#    1.795327e+02  1.476184e+02  1.703943e+02  1.218194e+02  5.258537e+01
#    3.308871e+01  3.840972e+01  4.424843e+01  6.957860e+01  4.019351e+00
#    3.050024e+00  3.039719e+00  2.996142e+00  2.967954e+00  1.999594e+00]
#  [ 2.000000e+00  3.042670e+01  3.347752e+01  4.480953e+01  6.247495e+01
#    7.743523e+01  1.042153e+02  1.027393e+02  1.370004e+02  1.860706e+02
#    2.193173e+02  1.817615e+02  1.209154e+02  1.431835e+02  8.240501e+01
# ...
