# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import plotly.graph_objects as go
from user_modules.plot_3d import plot_3d

data = pd.read_csv(r'C:\Users\nadys\Desktop\Projects\data\states.csv')

X = data[['white', 'hs_grad']]
y = data['poverty']

model = LinearRegression()
model.fit(X, y)

plot_3d(surface=True, scatter=True,
        X=X, Y=y,
        x1_max=97, x1_min=25,
        x2_max=92, x2_min=77,
        x=data.white, y=data.hs_grad, z=data.poverty,
        xaxis_title='white', yaxis_title='hs_grad', zaxis_title='poverty')
# Out:
# c:\Users\nadys\Desktop\Projects\myenv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names

# %%
data

# n = data.to_numpy()

# print(n)
# Out:
#                     state  metro_res  white  hs_grad  poverty  female_house
# 0                 Alabama       55.4   71.3     79.9     14.6          14.2
# 1                  Alaska       65.6   70.8     90.6      8.3          10.8
# 2                 Arizona       88.2   87.7     83.8     13.3          11.1
# 3                Arkansas       52.5   81.0     80.9     18.0          12.1
# 4              California       94.4   77.5     81.1     12.8          12.6
# 5                Colorado       84.5   90.2     88.7      9.4           9.6
# 6             Connecticut       87.7   85.4     87.5      7.8          12.1
# 7                Delaware       80.1   76.3     88.7      8.1          13.1
# 8   District  of Columbia      100.0   36.2     86.0     16.8          18.9
# 9                 Florida       89.3   80.6     84.7     12.1          12.0
# 10                Georgia       71.6   67.5     85.1     12.1          14.5
# ...
